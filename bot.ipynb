# %%
#BIBLIOTECAS NECESSÁRIAS
import requests as r
import time as t
import pandas as pd
import pyautogui as py
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as ec
from selenium.webdriver.support.wait import WebDriverWait 
from selenium.common.exceptions import NoSuchElementException

# %%
url = "https://www.instagram.com"

xpathlogin= "/html/body/div[1]/div/div/div/div[1]/div/div/div/div[1]/section/main/article/div[2]/div[1]/div[2]/form/div/div[1]/div/label/input"
xpathsenha="/html/body/div[1]/div/div/div/div[1]/div/div/div/div[1]/section/main/article/div[2]/div[1]/div[2]/form/div/div[2]/div/label/input"
xpathconfirmar = "/html/body/div[1]/div/div/div/div[1]/div/div/div/div[1]/section/main/article/div[2]/div[1]/div[2]/form/div/div[3]/button"

login=input("Digite nome de usuario: ")
senha=input("Digite sua senha: ")

executable_path="msedgedriver.exe"
driver = webdriver.Edge()

driver.get(url)
#driver.minimize_window()
driver.switch_to.default_content()

#SELECIONA CAMPO DO USUÁRIO
WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,xpathlogin)))
element = driver.find_element(By.XPATH,xpathlogin)
print("Coloquei o usuário")

#COLOCA LOGIN
element.send_keys(login)

#SELECIONA CAMPO DA SENHA
WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,xpathsenha)))
element = driver.find_element(By.XPATH,xpathsenha)
print("Coloquei a senha")

#COLOCA SENHA
element.send_keys(senha)

#SELECIONA BOTÂO CONFIRMAR
WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,xpathconfirmar)))
element = driver.find_element(By.XPATH,xpathconfirmar)

#CLICA EM CONFIRMAR
element.click()
print("Loguei")

#CLICA EM AGORA NÃO
xpathagoranao = '/html/body/div[1]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]'
WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,xpathagoranao)))
agoranao=len(driver.find_elements(By.XPATH,xpathagoranao))


if(agoranao>=1):
    element=driver.find_element(By.XPATH,xpathagoranao)
    element.click()
    print("Recusar")


#CLICA EM AGORA NÃO
xpathagoranao = '/html/body/div[1]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]'
WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,xpathagoranao)))
agoranao=len(driver.find_elements(By.XPATH,xpathagoranao))

if(agoranao>=1):
    element=driver.find_element(By.XPATH,xpathagoranao)
    element.click()
    print("Recusar")

url2 = input("Digite o url da publi: ")

while(url2!=""):
    driver.get(url2)
    print("Acessei a publicação")

    #ACESSA AS CURTIDAS
    linkcurtidas = "/html/body/div[1]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/div[1]/div[1]/article/div/div[2]/div/div[2]/section[2]/div/div/div/a/div/span"
    WebDriverWait(driver, 100).until(ec.presence_of_element_located((By.XPATH,linkcurtidas)))
    element=driver.find_element(By.XPATH,linkcurtidas)
    element.click()
    print("Acessei as curtidas")

    lengthlikes = 1
    i=0
    #/html/body/div[1]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div[2]/div/div/div[1]/div[3]/button
    #/html/body/div[1]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div[2]/div/div/div[2]/div[3]/button/div/div/div
    t.sleep(2)
    seguir = driver.find_elements(By.CSS_SELECTOR,"._acan._acap._acas")
    print("Procurando botões de seguir, achei "+str(len(seguir)))
    for i in range(len(seguir)):
        #driver.execute_script("document.querySelectorAll('._acan._acap._acas')["+str(i)+"].scrollIntoView({block: 'center'})")
        #driver.execute_script("document.querySelectorAll('._acan._acap._acas')["+str(i)+"].click()")
        #lengthlikes = len(driver.find_elements(By.TAG_NAME,"button"))
        seguir[i].click()
        
    url2 = input("Digite o url da publi: ")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# c:\Users\Rafael Granja\OneDrive - Universidade Federal de Minas Gerais\Programação\Python\Python\BotInstagram\bot.ipynb Célula: 3 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafael%20Granja/OneDrive%20-%20Universidade%20Federal%20de%20Minas%20Gerais/Programa%C3%A7%C3%A3o/Python/Python/BotInstagram/bot.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> driver.get(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/Rafael%20Granja/OneDrive%20-%20Universidade%20Federal%20de%20Minas%20Gerais/Programa%C3%A7%C3%A3o/Python/Python/BotInstagram/bot.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> #driver.minimize_window()
# ...
